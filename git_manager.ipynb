# %%
# 매번 실행
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 매번 실행
# %cd /content/drive/MyDrive/Colab Notebooks/interaction-llm-research
# Out:
# /content/drive/MyDrive/Colab Notebooks/interaction-llm-research

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/interaction-llm-research/.git/

# %%
# !git config --global inin.defaultBranch main

# %%
# !git pull origin main
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git status

# %%
# 모든 변경 사항 추가
# !git add .

# 커밋 메시지 작성 (메시지는 매번 수정)
# !git commit -m "Updated results and analysis in GNN-Only notebook"

# GitHub에 업로드
# !git push -u origin main
