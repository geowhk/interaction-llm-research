# %%
# 매번 실행
from google.colab import drive
drive.mount('/content/drive')

# %%
# 매번 실행
# %cd /content/drive/MyDrive/Colab Notebooks/interaction-llm-research
# Out:
# /content/drive/MyDrive/Colab Notebooks/interaction-llm-research

# %%
# !git add .

# %%
# !git commit -m "Initial commit: Set up project structure and notebooks"
# Out:
# [master (root-commit) a2d2ef7] Initial commit: Set up project structure and notebooks
#  1 file changed, 1 insertion(+)
#  create mode 100644 git_manager.ipynb

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.name "geowhk"

# %%
# !git remote remove origin

# %%
# !git config pull.rebase false

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# From https://github.com/geowhk/interaction-llm-research
#  * branch            main       -> FETCH_HEAD
# </interaction-llm-research/.git/MERGE_MSG" 6L, 300B▽  Pzz\[0%m           [>cMerge branch 'main' of https://github.com/geowhk/interaction-llm-research
# # Please enter a commit message to explain why this merge is necessary,# especially if it merges an updated upstream into a topic branch.#
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ...

# %%
from google.colab import userdata
github_token = userdata.get('Github_token')

# !git remote add origin https://{github_token}@github.com/geowhk/interaction-llm-research.git
# Out:
# error: remote origin already exists.

# %%
# !git push -u origin main
# Out:
# To https://github.com/geowhk/interaction-llm-research.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/geowhk/interaction-llm-research.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull origin main
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git status

# %%
# 모든 변경 사항 추가
# !git add .

# 커밋 메시지 작성 (메시지는 매번 수정)
# !git commit -m "Updated results and analysis in GNN-Only notebook"

# GitHub에 업로드
# !git push -u origin main
